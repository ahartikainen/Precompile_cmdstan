# %%
import cmdstanpy

# %% [markdown]
# ### Fail to compile (no cmdstan defined)

# %%
cmdstanpy.cmdstan_path()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-c24e465002d3> in <module>()
# ----> 1 cmdstanpy.cmdstan_path()
#
# c:\users\username\install_loc\cmdstanpy\cmdstanpy\utils.py in cmdstan_path()
#      81             )
#      82         cmdstan_path = os.path.join(cmdstan_dir, latest_cmdstan)
# ---> 83     validate_cmdstan_path(cmdstan_path)
#      84     return cmdstan_path
#      85
#
# c:\users\username\install_loc\cmdstanpy\cmdstanpy\utils.py in validate_cmdstan_path(path)
#      40     if not os.path.exists(os.path.join(path, 'bin', 'stanc' + EXTENSION)):
#      41         raise ValueError(
# ---> 42             'no CmdStan binaries found, '
#      43             'run command line script "install_cmdstan"'
#      44         )
#
# ValueError: no CmdStan binaries found, run command line script "install_cmdstan"

# %% [markdown]
# # Create model

# %%
# Will automatically find exe file if in default location, but defined here explicitly
model = cmdstanpy.Model(stan_file="./bernoulli.stan", exe_file="./bernoulli.exe")

# %%
fit = cmdstanpy.sample(stan_model=model, data="./bernoulli.data.json")
# Out:
# start chain 1.
# finish chain 1.
# start chain 2.
# finish chain 2.
# start chain 3.
# finish chain 3.
# start chain 4.
# finish chain 4.

# %% [markdown]
# # fail summary

# %%
cmdstanpy.summary(fit)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-ba9c182908ea> in <module>()
# ----> 1 cmdstanpy.summary(fit)
#
# c:\users\username\install_loc\cmdstanpy\cmdstanpy\cmds.py in summary(runset)
#     342     """
#     343     names = runset.column_names
# --> 344     cmd_path = os.path.join(cmdstan_path(), 'bin', 'stansummary' + EXTENSION)
#     345     tmp_csv_file = 'stansummary-{}-{}-chains-'.format(
#     346         runset.model, runset.chains
#
# c:\users\username\install_loc\cmdstanpy\cmdstanpy\utils.py in cmdstan_path()
#      81             )
#      82         cmdstan_path = os.path.join(cmdstan_dir, latest_cmdstan)
# ---> 83     validate_cmdstan_path(cmdstan_path)
#      84     return cmdstan_path
#      85
#
# c:\users\username\install_loc\cmdstanpy\cmdstanpy\utils.py in validate_cmdstan_path(path)
# ...

# %% [markdown]
# # Run summary with ArviZ

# %%
import arviz as az
az.style.use("arviz-darkgrid")

# %%
summary = az.summary(fit)
summary
# Out:
#         mean     sd  hpd_3%  hpd_97%  mcse_mean  mcse_sd  ess_mean  ess_sd  \
# theta  0.249  0.121   0.045    0.475      0.003    0.002    1452.0  1452.0
#
#        ess_bulk  ess_tail  r_hat
# theta    1354.0    1532.0    1.0

# %%
az.plot_posterior(fit)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001FCDDA75208>],
#       dtype=object)

# %%
az.plot_trace(fit)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FCDE243358>,
# ...
#       dtype=object)
